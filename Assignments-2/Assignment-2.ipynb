# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
pd.set_option("display.max_columns", None)

# %%
# Load Dataset

df = pd.read_csv("netflix_titles.csv")

df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
# Check Data Types

df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# Convert date column to datetime

df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
# Detect Missing Values

df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        98
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Create Missing Values for testing

df_missing = df.copy()

df_missing.loc[0:5, 'release_year'] = np.nan

df_missing.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        98
# release_year       6
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Check dataset size

print("Original shape:", df.shape)

print("After adding missing values:", df_missing.shape)
# Out:
# Original shape: (8807, 12)
# After adding missing values: (8807, 12)

# %%
# Preview dataset

df_missing.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
# Remove Missing Values

df_removed = df_missing.dropna()

df_removed.shape
# Out:
# (5328, 12)

# %%
# Check Missing Values after removing

df_removed.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# Fill Missing Values using Mean

df_imputed_mean = df_missing.copy()

mean_value = df_imputed_mean['release_year'].mean()

df_imputed_mean['release_year'] = df_imputed_mean['release_year'].fillna(mean_value)

df_imputed_mean.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        98
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Preview dataset

df_imputed_mean.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
# Fill Missing Values using Median

df_imputed_median = df_missing.copy()

median_value = df_imputed_median['release_year'].median()

df_imputed_median['release_year'] = df_imputed_median['release_year'].fillna(median_value)

df_imputed_median.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        98
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Preview dataset

df_imputed_median.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
# Detect Outliers using Boxplot

plt.figure(figsize=(4,3))

sns.boxplot(x=df['release_year'])

plt.title("Boxplot of Release Year")

plt.show()

# %%
# Detect Outliers using IQR

Q1 = df['release_year'].quantile(0.25)

Q3 = df['release_year'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR

upper = Q3 + 1.5 * IQR

outliers = df[(df['release_year'] < lower) | (df['release_year'] > upper)]

outliers.head(15)
# Out:
#     show_id     type                                              title  \
# 7        s8    Movie                                            Sankofa
# 22      s23    Movie                                    Avvai Shanmughi
# 24      s25    Movie                                              Jeans
# 26      s27    Movie                                     Minsara Kanavu
# 41      s42    Movie                                               Jaws
# 42      s43    Movie                                             Jaws 2
# 43      s44    Movie                                             Jaws 3
# 44      s45    Movie                                  Jaws: The Revenge
# 48      s49    Movie                                       Training Day
# 51      s52    Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# 52      s53    Movie  InuYasha the Movie 3: Swords of an Honorable R...
# 54      s55    Movie  InuYasha the Movie: Affections Touching Across...
# ...

# %%
# Remove Outliers

df_no_outliers = df[(df['release_year'] >= lower) & (df['release_year'] <= upper)]

print("Original shape:", df.shape)

print("After removing outliers:", df_no_outliers.shape)
# Out:
# Original shape: (8807, 12)
# After removing outliers: (8088, 12)

# %%
# Cap Outliers

lower_cap = df['release_year'].quantile(0.05)

upper_cap = df['release_year'].quantile(0.95)

df_capped = df.copy()

df_capped['release_year'] = df_capped['release_year'].clip(lower_cap, upper_cap)

# %%
# Create new numeric feature

df_pca = df.copy()

df_pca['date_added'] = pd.to_datetime(df_pca['date_added'], errors='coerce')

df_pca['year_added'] = df_pca['date_added'].dt.year

df_pca[['release_year', 'year_added']].head()
# Out:
#    release_year  year_added
# 0          2020      2021.0
# 1          2021      2021.0
# 2          2021      2021.0
# 3          2021      2021.0
# 4          2021      2021.0

# %%
# Handle missing values before scaling

df_pca[['release_year', 'year_added']] = df_pca[['release_year', 'year_added']].fillna(
    df_pca[['release_year', 'year_added']].median()
)

df_pca[['release_year', 'year_added']].isna().sum()
# Out:
# release_year    0
# year_added      0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_scaled = df_pca[['release_year', 'year_added']].copy()

df_scaled[['release_year', 'year_added']] = scaler.fit_transform(df_scaled)

df_scaled.head()
# Out:
#    release_year  year_added
# 0      0.989583         1.0
# 1      1.000000         1.0
# 2      1.000000         1.0
# 3      1.000000         1.0
# 4      1.000000         1.0

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_standardized = df_pca[['release_year', 'year_added']].copy()

df_standardized[['release_year', 'year_added']] = scaler.fit_transform(df_standardized)

df_standardized.head()
# Out:
#    release_year  year_added
# 0      0.659930    1.353813
# 1      0.773324    1.353813
# 2      0.773324    1.353813
# 3      0.773324    1.353813
# 4      0.773324    1.353813

# %%
plt.figure(figsize=(6,4))

sns.heatmap(df_standardized[['release_year', 'year_added']].corr(),
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %%
from sklearn.decomposition import PCA

X = df_standardized[['release_year', 'year_added']]

pca = PCA(n_components=2)

principal_components = pca.fit_transform(X)

print("Explained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio: [0.55490208 0.44509792]

# %%
plt.figure(figsize=(6,4))

plt.scatter(principal_components[:,0], principal_components[:,1])

plt.title("PCA Projection")

plt.xlabel("Principal Component 1")

plt.ylabel("Principal Component 2")

plt.show()
